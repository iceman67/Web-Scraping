# %%
2018 worlcup players

Web Scraping Using Python and BeautifulSoup

https://towardsdatascience.com/web-scraping-5649074f3ead

# %%
import requests
from bs4 import BeautifulSoup

#Request URL
page = requests.get("https://www.fifa.com/worldcup/players/player/201200/profile/")

#Fetch webpage
soup = BeautifulSoup(page.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-GB">
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <link href="/worldcup/players/player/201200/profile/" rel="canonical"/>
#   <meta content="WIYA_sQFwaqCYhFPJH-ubd_gYNDzhd6oi2niDYgPFII" name="google-site-verification"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon.ico" rel="shortcut icon"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_16.png" rel="icon" sizes="16x16"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_32.png" rel="icon" sizes="32x32"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon.ico" rel="icon" sizes="16x16 32x32 48x48 128x128 256x256 512x512"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_192.png" rel="icon" sizes="192x192"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_180.png" rel="apple-touch-icon" sizes="180×180"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_167.png" rel="apple-touch-icon" sizes="167×167"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_152.png" rel="apple-touch-icon" sizes="152×152"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_144.png" rel="apple-touch-icon" sizes="144×144"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_120.png" rel="apple-touch-icon" sizes="120×120"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_114.png" rel="apple-touch-icon" sizes="114×114"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_72.png" rel="apple-touch-icon" sizes="72×72"/>
#   <link href="https://img.fifa.com/image/upload/t_fe-auto/assets/img/icons/favicon_57.png" rel="apple-touch-icon"/>
#   <link href="https://www.googletagservices.com" rel="dns-prefetch preconnect"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch preconnect"/>
#   <link href="https://assets.adobedtm.com" rel="dns-prefetch preconnect"/>
#   <link href="https://adservice.google.it" rel="dns-prefetch preconnect"/>
#   <link href="https://cdn.ampproject.org" rel="dns-prefetch preconnect"/>
#   <link href="/CompiledAssets/css/fonts.css?_t=ca6a41678a1103698b036d3efba43130" rel="stylesheet" type="text/css">
#    <link href="/CompiledAssets/css/modules/empty.css?_t=1a34a4f3a5c72f302867bd6c8322ffc5" rel="stylesheet" type="text/css">
#     <title>
#      2018 FIFA World Cup Russia™  - Players - CRISTIANO RONALDO - Cristiano Ronaldo - FIFA.com
#     </title>
#     <meta content="The Real Madrid forward is Portugal’s captain, most capped player and leading all-time goalscorer. Still supremely fit and as committed as ever, he is more of a penalty box operator these days, having lost none of his scoring touch or his gift for breaking records." name="description"/>
#     <meta content="Cristiano,Ronaldo" name="keywords"/>
#     <meta content="" http-equiv="Content-Type"/>
#     <meta content="noodp" name="robots"/>
#     <meta content="FIFA.com" name="author"/>
#     <meta content="https://img.fifa.com/image/upload/t_fe-auto/assets/img/template/og_image.png" name="thumb"/>
#     <!-- FACEBOOK -->
#     <meta content="2018 FIFA World Cup Russia™  - Players - CRISTIANO RONALDO - Cristiano Ronaldo - FIFA.com" property="og:title">
#      <meta content="The Real Madrid forward is Portugal’s captain, most capped player and leading all-time goalscorer. Still supremely fit and as committed as ever, he is more of a penalty box operator these days, having lost none of his scoring touch or his gift for breaking records." property="og:description">
#       <meta content="en-GB" property="og:locale">
#        <meta content="www.fifa.com" property="og:site_name">
#         <meta content="https://www.fifa.com/worldcup/players/player/201200/profile/" property="og:url"/>
#         <meta content="article" property="og:type"/>
#         <meta content="https://img.fifa.com/image/upload/t_fe-auto/assets/img/template/og_image.png" property="og:image"/>
#         <meta content="png" property="og:image:type"/>
#         <meta content="1200" property="og:image:width"/>
#         <meta content="630" property="og:image:height"/>
#         <!-- TWITTER -->
#         <meta content="2018 FIFA World Cup Russia™  - Players - CRISTIANO RONALDO - Cristiano Ronaldo - FIFA.com" name="twitter:title">
#          <meta content="The Real Madrid forward is Portugal’s captain, most capped player and leading all-time goalscorer. Still supremely fit and as committed as ever, he is more of a penalty box operator these days, having lost none of his scoring touch or his gift for breaking records." name="twitter:description">
#           <meta content="https://img.fifa.com/image/upload/t_fe-auto/assets/img/template/og_image.png" name="twitter:image"/>
#           <meta content="https://img.fifa.com/image/upload/t_fe-auto/assets/img/template/og_image.png" name="twitter:image:src"/>
#           <meta content="summary_large_image" name="twitter:card"/>
#           <meta content="@fifacom" name="twitter:site">
#            <meta content="@fifacom" name="twitter:creator"/>
#            <meta content="www.fifa.com" name="twitter:domain"/>
#            <!-- OTHERS -->
#            <meta content="worldcup" name="others:cupfolder"/>
#            <link as="style" href="/CompiledAssets/css/base.css?_t=eb2be77fbb2eff3b3264bf860df1ca84" rel="prefetch">
#             <link href="/CompiledAssets/css/sections/tournaments/trn-header.css?_t=b4c8c4227196920a44bbeecae312404b" rel="stylesheet" type="text/css">
#              <!--[if lte IE 9]>
#    <link href="/CompiledAssets/css/base-ie.css?_t=ee8659d32d45a91e40d54e728e6bce64" rel="stylesheet" type="text/css" />
#                 <![endif]-->
#              <link href="/CompiledAssets/css/base.css?_t=eb2be77fbb2eff3b3264bf860df1ca84" rel="stylesheet" type="text/css">
#               <link href="/compiledAssets/css/sections/tournaments/fwc/2018/footballdata/players.css?_t=2b407466a5b975ded5b3907004ba76be" rel="stylesheet" type="text/css"/>
#               <link href="/CompiledAssets/css/sections/tournaments/fwc/2018/editorial/fwc-article.css?_t=ae6f74f78acf3d9f2da47651dfb60def" rel="stylesheet" type="text/css"/>
#               <link href="/CompiledAssets/css/sections/tournaments/fwc/2018/fwc.css?_t=f2fe1e141126804bdfb6eba4c46fccc2" rel="stylesheet" type="text/css"/>
#               <link as="script" href="/CompiledAssets/js/vendor/requirejs/require-2.2.0.min.js?_t=5a25cd3d1c6c9687e2ccee58c3b25df2" rel="prefetch"/>
#               <link as="script" href="/CompiledAssets/js/main.js?_t=011874d8d3806cdec1afad67a084a125" rel="prefetch"/>
#               <link as="script" href="/CompiledAssets/js/vendor/objectFillPolyfill/ofi.min.js?_t=0e0a0cdb22d6031d47bb1aeffe7b0b48" rel="prefetch"/>
#               <link as="script" href="/CompiledAssets/js/vendor/picturefill/picturefill.min.js?_t=f18e527d6c7504f27ce456f316385430" rel="prefetch"/>
#               <script>
#                // Picture element HTML5 shiv
#     document.createElement("picture");
#               </script>
#               <script async="" src="//assets.adobedtm.com/e6e5367e7206af04b18c52d468382cd2994fde50/satelliteLib-c0590439d6ba99abb888b267957affb2468f7dd1.js" type="text/javascript">
#               </script>
#               <script src="/CompiledAssets/js/vendor/requirejs/require-2.2.0.min.js?_t=5a25cd3d1c6c9687e2ccee58c3b25df2" type="text/javascript">
#               </script>
#               <script src="/CompiledAssets/js/main.js?_t=011874d8d3806cdec1afad67a084a125" type="text/javascript">
#               </script>
#               <script src="/CompiledAssets/js/vendor/objectFillPolyfill/ofi.min.js?_t=0e0a0cdb22d6031d47bb1aeffe7b0b48" type="text/javascript">
#               </script>
#               <script async="" src="/CompiledAssets/js/vendor/picturefill/picturefill.min.js?_t=f18e527d6c7504f27ce456f316385430" type="text/javascript">
#               </script>
#               <script type="application/ld+json">
#                {
#   "@context": "http://schema.org/",
#   "@type": "Organization",
#   "url": "https://www.fifa.com",
#   "logo": "https://img.fifa.com/image/upload/t_fe-auto/assets/img/layout/brand/fifa-logo.jpg"
#   }
#               </script>
#               <script type="application/ld+json">
#                {
#   "@context": "http://schema.org",
#   "@type": "WebSite",
#   "url": "https://www.fifa.com",
#   "potentialAction": {
#   "@type": "SearchAction",
#   "target": "https://www.fifa.com/?q={search_term_string}",
#   "query-input": "required name=search_term_string"
#   }
#   }
#               </script>
#               <script>
#                var Global = {
#         culture: "en-GB",
#       cultureCode: "en-GB",
#       environment: "PRD",
#       platform: "default"
#     };
#     //window.rjspaths = {};
#               </script>
#               <script type="text/javascript">
#                window.digitalData = {
#     page: {
#       pageInfo: {
#         //sysEnv: 'web',
#         //destinationURL: window.location.href
#       },
#       attributes: {
#       }
#     },
#     component: [],
#     user: {
#       profile: {}
#     },
#     event: {
#       eventInfo: {}
#     }
#   };
#
#   digitalData.page.attributes.type = 'hub';
#               </script>
#               <script type="text/javascript">
#                digitalData.page.attributes.competitionName = '2018 FIFA World Cup Russia™ ';
#       digitalData.page.attributes.competitionID = '17';
#       digitalData.page.attributes.competitionEdition = '2018';
#       digitalData.page.attributes.campaignName = '';
#               </script>
#               <script type="text/javascript">
#                if (digitalData.component) {
#     var contentComponent = {
#       componentInfo: {}
#     }
#
#
#
#
#
#
#     digitalData.component.push(contentComponent);
#   }
#               </script>
#               <script async="" src="/CompiledAssets/js/vendor/lazysizes/lazysizes.min.js?_t=739e7d27e1cbc58b1b2e6882674b8867" type="text/javascript">
#               </script>
#              </link>
#             </link>
#            </link>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body class="worldcup players player 201200 profile sticky--enabled">
#   <svg height="0" style="position: absolute; width: 0; height: 0;" version="1.1" width="0" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <defs>
#     <svg height="100%" id="icon-fifacom-logo" viewbox="0 0 111.72 20" width="100%">
#      <defs>
#       <style>
#        .fi-iconFifaPrefixfifacom-logo--1, .fi-iconFifaPrefixfifacom-logo--3 {
# 										fill: #326295;
# 								}
#
# 								.fi-iconFifaPrefixfifacom-logo--2 {
# 										fill: #ffcc00;
# 								}
#       </style>
#      </defs>
#      <g data-name="Layer 2" id="Layer_2">
#       <g data-name="Layer 1" id="Layer_1-2">
#        <polygon class="fi-iconFifaPrefixfifacom-logo--1" points="15.35 0 13.73 4.36 6.32 4.36 6.32 8.41 12.41 8.41 10.7 12.78 6.32 12.78 6.32 20 0 20 0 0 15.35 0 15.35 0">
#        </polygon>
#        <polygon class="fi-iconFifaPrefixfifacom-logo--1" points="17.29 0 17.28 20 23.52 20 23.52 0 17.29 0 17.29 0">
#        </polygon>
#      <path d="M73.189,50.091c-1.373-0.417-2.314-0.705-1.596-2.539c1.555-3.985,1.718-7.422,0.031-9.874c-3.164-4.6-11.818-4.353-21.735-0.123c0-0.005-3.116,1.387-2.32-1.129c1.526-4.994,1.294-9.174-1.078-11.589c-5.38-5.481-19.691,0.208-31.967,12.696C5.334,46.889,0,56.806,0,65.38c0,16.399,20.66,27.37,40.874,27.37C67.371,92.75,85,76.08,85,63.639C85,56.12,78.779,51.854,73.189,50.091z M40.929,85.397c-16.13,1.598-30.051-5.729-31.1-16.38c-1.047-10.646,11.182-20.578,27.31-22.181c16.131-1.606,30.055,5.727,31.1,16.373C69.283,73.86,57.062,83.793,40.929,85.397zM99.5,36.737C99.492,20.175,86.065,6.75,69.5,6.75c-1.934,0-3.5,1.567-3.5,3.5c0,1.934,1.566,3.5,3.5,3.5c12.703,0,23,10.298,23,23c0,1.934,1.568,3.5,3.5,3.5c1.934,0,3.5-1.566,3.5-3.5C99.5,36.75,99.5,36.742,99.5,36.737zM85.593,36.223c-1.599-7.809-7.755-13.964-15.565-15.564c-1.891-0.389-3.742,0.83-4.13,2.723c-0.39,1.893,0.829,3.742,2.72,4.133c5.078,1.04,9.08,5.039,10.119,10.117c0.391,1.893,2.24,3.111,4.133,2.723C84.762,39.964,85.98,38.115,85.593,36.223zM32.656,57.264c-6.498,1.306-10.882,6.755-9.794,12.169c1.087,5.415,7.237,8.745,13.735,7.438c6.496-1.306,10.882-6.753,9.793-12.169C45.304,59.289,39.152,55.958,32.656,57.264z" transform="translate(0 -10.8)">
#      </path>
#     </symbol>
#    </defs>
#   </svg>
#   <header class="fi-site-header fi-site-header--competition ">
#    <div class="fi-site-header__top" data-asset="header-banner">
#     <div class="container-fluid">
#      <!--FIFA.com LOGO-->
#      <div class="fi-site-brand">
#       <a class="fi-site-brand__logo" href="/index?nav=internal">
#       </a>
#      </div>
#      <!--TOP HEADER-->
#      <div class="fi-site-header__nav">
#       <!--MAIN MENU-->
#       <ul class="fi-icons-bar">
#        <li class="fi-icons-bar__ticket">
#         <a href="/tickets" title="Tickets">
#          <svg class="fi-svg-icon icon-ticket">
#           <use xlink:href="#icon-ticket">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="fi-icons-bar__store">
#         <a href="/store/" title="Store">
#          <svg class="fi-svg-icon icon-basket">
#           <use xlink:href="#icon-basket">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="fi-icons-bar__login">
#         <a data-dropdown="fi-site-header__dropdown__login" href="#" title="Login">
#          <svg class="fi-svg-icon icon-login">
#           <use xlink:href="#icon-login">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="fi-icons-bar__lang">
#         <a data-dropdown="fi-site-header__dropdown__lang" href="#">
#          EN
#         </a>
#        </li>
#        <li class="fi-icons-bar__search">
#         <a data-dropdown="fi-site-header__dropdown__search" href="#" title="Search">
#          <svg class="fi-svg-icon icon-search">
#           <use xlink:href="#icon-search">
#           </use>
#          </svg>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <!--MAIN HEADER-->
#    <div class="fi-site-header__main">
#     <div class="container-fluid">
#      <!--SOCIAL-->
#     </div>
#    </div>
#    <!-- SIDE-MENU -->
#    <div class="fi-site-header__dropdown-wrap">
#     <div class="container-fluid">
#      <span class="fi-site-header__dropdown__close hidden">
#       <svg class="fi-svg-icon icon-close">
#        <use xlink:href="#icon-close">
#        </use>
#       </svg>
#      </span>
#      <div class="fi-site-header__dropdown__main fi-site-header__dropdown--vertical hidden">
#       <div class="fi-site-header__dropdown__main-wrap">
#        <div class="clearfix">
#         <!-- Editorial menu -->
#         <ul class="nav nav-media">
#          <li>
#           <a href="/news/">
#            News
#           </a>
#          </li>
#          <li>
#           <a href="/photos/">
#            Photos
#           </a>
#          </li>
#          <li>
#           <a href="/videos/">
#            Videos
#           </a>
#          </li>
#         </ul>
#         <!-- Section menu -->
#         <ul class="nav">
#          <li>
#           <a href="/visual-stories/">
#            Visual Stories
#           </a>
#          </li>
#          <li>
#           <a class="fi-ltr--force" href="/worldcup/qatar2022/">
#            FIFA World Cup™
#           </a>
#          </li>
#          <li>
#           <a href="/womensworldcup/">
#            FIFA Women's World Cup™
#           </a>
#          </li>
#          <li>
#           <a href="/fifa-tournaments/">
#            Tournaments
#           </a>
#          </li>
#          <li>
#           <a href="/tickets/">
#            Ticketing
#           </a>
#          </li>
#          <li>
#           <a class="fi-ltr--force" href="/fifaeworldcup/">
#            FIFA eWorld Cup™
#           </a>
#          </li>
#          <li>
#           <a class="fi-ltr--force" href="/the-best-fifa-football-awards/">
#            The Best FIFA Football Awards™
#           </a>
#          </li>
#          <li>
#           <a href="/fifa-world-ranking/">
#            Ranking
#           </a>
#          </li>
#          <li>
#           <a href="/about-fifa/who-we-are/">
#            Who We Are
#           </a>
#          </li>
#          <li>
#           <a href="/about-fifa/what-we-do/">
#            What We Do
#           </a>
#          </li>
#          <li>
#           <a href="/fifa-tournaments/fan-movement/">
#            Fan Movement
#           </a>
#          </li>
#          <li>
#           <a href="/about-fifa/who-we-are/official-documents/">
#            Official Documents
#           </a>
#          </li>
#          <li>
#           <a class="fi-ltr--force" href="/about-fifa/what-we-do/fifa-forward-programme/">
#            FIFA Forward
#           </a>
#          </li>
#          <li>
#           <a href="/about-fifa/what-we-do/fifa-foundation/">
#            FIFA Foundation
#           </a>
#          </li>
#          <li>
#           <a href="/womens-football/">
#            Women's Football
#           </a>
#          </li>
#          <li>
#           <a href="/about-fifa/who-we-are/media/">
#            Media
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- Search menu -->
#        <div class="fi-search">
#         <div class="form-group">
#          <form action="/search/index" method="get">
#           <input class="fi-search__text" data-required="true" maxlength="100" name="q" placeholder="Search on FIFA.com" title="Search" type="text"/>
#           <div class="fi-search__submit-wrap">
#            <label>
#             <input class="btn btn-primary fi-btn--submit" type="submit" value=""/>
#             <svg class="fi-svg-icon icon-search">
#              <use xlink:href="#icon-search">
#              </use>
#             </svg>
#            </label>
#           </div>
#          </form>
#         </div>
#        </div>
#        <!--SOCIAL CHANNELS-->
#       </div>
#      </div>
#      <!-- LOGIN -->
#      <div class="fi-site-header__dropdown__login fi-site-header__dropdown--vertical is-notlogged hidden">
#       <div class="fi-login fi-login--not-logged" data-lang="">
#        <div class="fi-login__theclub-logo__wrap">
#         <img alt="The Club" class="fi-login__theclub-logo lazyload" data-src="https://img.fifa.com/image/upload/t_fe-auto/assets/img/layout/theclub/theClub.png"/>
#        </div>
#        <div class="fi-login__form">
#         <p class="fi-login__desc">
#          Please sign in to your FIFA.com user account below. This will allow you to make the most of your account with personalization. You’ll also get exclusive access to FIFA games, contests and prizes.
#         </p>
#         <div class="fi-login__theclub form-group">
#          <a class="fi-login-signin-link" href="https://account.fifa.com/5a7baeb7-e706-4830-ad9f-103eba126311/oauth2/v2.0/authorize?p=b2c_1a_fifa_signuporsignin&amp;client_Id=64e9afa8-c5c0-413d-882b-bc9e6a81e264&amp;nonce=defaultNonce&amp;prompt=login&amp;redirect_uri=https%3A%2F%2Fwww.fifa.com%2Ftheclub%2Ftools%2Fcomment%2F_ms_login_handler.htmx&amp;scope=openid%20offline_access&amp;response_type=code&amp;response_mode=form_post" id="fi-login-signin-link">
#           <div class="fi-login__submit-wrap">
#            <input class="btn btn-primary fi-btn--submit" type="submit" value="Login"/>
#           </div>
#          </a>
#         </div>
#         <div class="fi-login__not-member form-group">
#          <p class="fi-login__not-member__desc">
#           Don't have an account yet?
#          </p>
#          <div class="fi-login__submit-wrap">
#           <input class="btn btn-primary-inverse fi-btn--submit" type="submit" value="Sign Up now"/>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="fi-login fi-login--logged" data-lang="">
#        <div class="fi-login__user">
#         <img alt="Login" class="fi-login__avatar"/>
#         <div class="fi-login__userinfo">
#          <h4 class="fi-login__username">
#           <a href="/theclub/profile/comments/index.html" target="_self">
#            {screenName}
#           </a>
#          </h4>
#         </div>
#        </div>
#        <div class="fi-login-out__theclub form-group" id="siteh-theclub-logout">
#         <a href="http://www.fifa.com/theclub/tools/comment/_ms_login_handler.htmx?logout=true" id="fi-logout-signout-link">
#          <div class="fi-login-out__submit-wrap">
#           <span class="btn btn-primary fi-btn--submit">
#            Log out
#           </span>
#          </div>
#         </a>
#        </div>
#       </div>
#       <script>
#        function getParameterByName(name, url) {
#         if (!url) url = window.location.href;
#         name = name.replace(/[\[\]]/g, "\\$&");
#         var regex = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)"),
#           results = regex.exec(url);
#         if (!results) return null;
#         if (!results[2]) return '';
#         return decodeURIComponent(results[2].replace(/\+/g, " "));
#       }
#       </script>
#      </div>
#      <!-- LANGUAGES -->
#      <div class="fi-site-header__dropdown__lang fi-site-header__dropdown--vertical hidden">
#       <ul class="nav nav-langs">
#        <li class="" data-value="en-GB">
#         <a href="https://en.fifa.com">
#          English
#         </a>
#        </li>
#        <li class="" data-value="de-DE">
#         <a href="https://de.fifa.com">
#          Deutsch
#         </a>
#        </li>
#        <li class="" data-value="fr-FR">
#         <a href="https://fr.fifa.com">
#          Français
#         </a>
#        </li>
#        <li class="" data-value="es-ES">
#         <a href="https://es.fifa.com">
#          Español
#         </a>
#        </li>
#        <li class="" data-value="ar-SA">
#         <a href="https://ar.fifa.com">
#          عربي
#         </a>
#        </li>
#        <li class="" data-value="ru-RU">
#         <a href="https://ru.fifa.com">
#          Русский
#         </a>
#        </li>
#        <li class="" data-value="ch-CH">
#         <a href="https://fifaofficial.cn">
#          简体中文
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="fi-site-header__dropdown__search hidden">
#       <div class="fi-search__wrap">
#        <div class="fi-search">
#         <div class="form-group">
#          <form action="/search/index" method="get">
#           <input class="fi-search__text" data-required="true" maxlength="100" name="q" placeholder="Search on FIFA.com" title="Search" type="text"/>
#           <div class="fi-search__submit-wrap">
#            <label>
#             <input class="btn btn-primary fi-btn--submit" type="submit" value=""/>
#             <svg class="fi-svg-icon icon-search">
#              <use xlink:href="#icon-search">
#              </use>
#             </svg>
#            </label>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="fi-section-header fi-section-header__extended ">
#    <div class="fi-section-header__wrap">
#     <a class="fi-section-header__emblem" href="/worldcup/?nav=internal" title="2018 FIFA World Cup Russia™">
#      <img alt="2018 FIFA World Cup Russia™" class="fi-section-header__emblem__img emblem-workaround" src="https://api.fifa.com/api/v1/picture/tournaments-sq-4/254645_w">
#      </img>
#     </a>
#     <a class="fi-section-header__competition" href="/worldcup/?nav=internal" title="2018 FIFA World Cup Russia™">
#      <h1 class="fi-section-header__competition__title">
#       2018 FIFA World Cup Russia™
#      </h1>
#      <p class="fi-section-header__competition__date">
#       14 June - 15 July
#      </p>
#     </a>
#     <div class="fi-section-header__social">
#      <ul class="fi-social-channels--svg">
#       <li>
#        <a class="fi-social-channels__fb--f" href="https://www.facebook.com/fifaworldcup" target="_blank">
#         <svg class="fi-svg-icon fi-icon-facebook-noframe">
#          <use xlink:href="#icon-facebook-noframe">
#          </use>
#         </svg>
#        </a>
#       </li>
#       <li>
#        <a class="fi-social-channels__tw--circle" href="https://twitter.com/FifaWorldCup" target="_blank">
#         <svg class="fi-svg-icon fi-icon-tw-noframe">
#          <use xlink:href="#icon-tw-noframe">
#          </use>
#         </svg>
#        </a>
#       </li>
#       <li>
#        <a class="fi-social-channels__instagram" href="https://www.instagram.com/fifaworldcup/" target="_blank">
#         <svg class="fi-svg-icon fi-icon-instagram-noframe">
#          <use xlink:href="#icon-instagram-noframe">
#          </use>
#         </svg>
#        </a>
#       </li>
#       <li>
#        <a class="fi-social-channels__youtube" href="https://www.youtube.com/FIFATV" target="_blank">
#         <svg class="fi-svg-icon fi-icon-youtube-noframe">
#          <use xlink:href="#icon-youtube-noframe">
#          </use>
#         </svg>
#        </a>
#       </li>
#       <li>
#        <a class="fi-social-channels__we--f" href="https://www.weibo.com/FIFAWorldCup?is_hot=1" target="_blank">
#         <svg class="fi-svg-icon fi-icon-weibo-noframe">
#          <use xlink:href="#icon-weibo-noframe">
#          </use>
#         </svg>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <ul class="fi-section-header__nav">
#      <li class="">
#       <a href="/worldcup/matches/">
#        Matches
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/teams/">
#        Teams
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/groups/">
#        Groups
#       </a>
#      </li>
#      <li class="active">
#       <a href="/worldcup/players/">
#        Players
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/statistics/">
#        Statistics
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/destination/">
#        Destination
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/fan-zone/">
#        Fan Zone
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/awards/">
#        Awards
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/organisation/ticketing/index.html">
#        Ticketing
#       </a>
#      </li>
#      <li class="">
#       <a href="/worldcup/classic/">
#        Classic
#       </a>
#      </li>
#     </ul>
#     <div class="fi-section-header__dropdown">
#      <ul>
#       <li>
#        <a class="fi-site-toggle" data-dropdown="fi-section-header__dropdown__hamburger" href="#">
#         <span class="fi-menu-toggle__inner">
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="fi-section-header__dropdown-wrap">
#     <div class="container-fluid">
#      <span class="fi-section-header__dropdown__close hidden">
#       <svg class="fi-svg-icon icon-close">
#        <use xlink:href="#icon-close">
#        </use>
#       </svg>
#      </span>
#      <div class="fi-section-header__dropdown__main fi-section-header__dropdown--vertical hidden">
#       <div class="fi-section-header__dropdown__main-wrap">
#        <div class="clearfix">
#         <a class="fi-section-header__competition--mobile" href="/worldcup/?nav=internal" title="2018 FIFA World Cup Russia™">
#          <h1 class="fi-section-header__competition__title">
#           2018 FIFA World Cup Russia™
#          </h1>
#         </a>
#         <ul class="fi-section-header__dropdown__nav">
#          <li class="news nav-media">
#           <a href="/worldcup/news/">
#            News
#           </a>
#          </li>
#          <li class="photos nav-media">
#           <a href="/worldcup/photos/">
#            Photos
#           </a>
#          </li>
#          <li class="videos nav-media">
#           <a href="/worldcup/videos/">
#            Videos
#           </a>
#          </li>
#          <li class="visual stories ">
#           <a href="/worldcup/visual-stories/">
#            Visual Stories
#           </a>
#          </li>
#          <li class="matches ">
#           <a href="/worldcup/matches/">
#            Matches
#           </a>
#          </li>
#          <li class="teams ">
#           <a href="/worldcup/teams/">
#            Teams
#           </a>
#          </li>
#          <li class="groups ">
#           <a href="/worldcup/groups/">
#            Groups
#           </a>
#          </li>
#          <li class="players ">
#           <a href="/worldcup/players/">
#            Players
#           </a>
#          </li>
#          <li class="statistics ">
#           <a href="/worldcup/statistics/">
#            Statistics
#           </a>
#          </li>
#          <li class="destination ">
#           <a href="/worldcup/destination/">
#            Destination
#           </a>
#          </li>
#          <li class="37974865-4e70-41cd-a8f6-2ddcd67de3f9 ">
#           <a href="/worldcup/fan-zone/">
#            Fan Zone
#           </a>
#          </li>
#          <li class="awards ">
#           <a href="/worldcup/awards/">
#            Awards
#           </a>
#          </li>
#          <li class="ticketing ">
#           <a href="/worldcup/organisation/ticketing/index.html">
#            Ticketing
#           </a>
#          </li>
#          <li class="organisation ">
#           <a href="/worldcup/organisation/">
#            Organisation
#           </a>
#          </li>
#          <li class="preliminaries ">
#           <a href="/worldcup/preliminaries">
#            Qualifiers
#           </a>
#          </li>
#          <li class="fd67ce16-53da-46e0-a106-8bf0c904817d ">
#           <a href="/worldcup/classic/">
#            Classic
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="fi-search">
#         <div class="form-group">
#          <form action="/search/index" method="get">
#           <input class="fi-search__text" data-required="true" maxlength="100" name="q" placeholder="Search on FIFA.com" title="Search" type="text"/>
#           <div class="fi-search__submit-wrap">
#            <label>
#             <input class="btn btn-primary fi-btn--submit" type="submit" value=""/>
#             <svg class="fi-svg-icon icon-search">
#              <use xlink:href="#icon-search">
#              </use>
#             </svg>
#            </label>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="fi-season-dropdown">
#         <div class="fi-filter-select">
#          <select id="edition-selector" name="edition-selector">
#           <option value="">
#            select edition
#           </option>
#           <option value="/worldcup/">
#            qatar2022
#           </option>
#           <option value="/worldcup/archive/russia2018/">
#            russia2018
#           </option>
#           <option value="/worldcup/archive/brazil2014/">
#            brazil2014
#           </option>
#           <option value="/worldcup/archive/southafrica2010/">
#            southafrica2010
#           </option>
#           <option value="/worldcup/archive/germany2006/">
#            germany2006
#           </option>
#           <option value="/worldcup/archive/koreajapan2002/">
#            koreajapan2002
#           </option>
#           <option value="/worldcup/archive/france1998/">
#            france1998
#           </option>
#           <option value="/worldcup/archive/usa1994/">
#            usa1994
#           </option>
#           <option value="/worldcup/archive/italy1990/">
#            italy1990
#           </option>
#           <option value="/worldcup/archive/mexico1986/">
#            mexico1986
#           </option>
#           <option value="/worldcup/archive/spain1982/">
#            spain1982
#           </option>
#           <option value="/worldcup/archive/argentina1978/">
#            argentina1978
#           </option>
#           <option value="/worldcup/archive/germany1974/">
#            germany1974
#           </option>
#           <option value="/worldcup/archive/mexico1970/">
#            mexico1970
#           </option>
#           <option value="/worldcup/archive/england1966/">
#            england1966
#           </option>
#           <option value="/worldcup/archive/chile1962/">
#            chile1962
#           </option>
#           <option value="/worldcup/archive/sweden1958/">
#            sweden1958
#           </option>
#           <option value="/worldcup/archive/switzerland1954/">
#            switzerland1954
#           </option>
#           <option value="/worldcup/archive/brazil1950/">
#            brazil1950
#           </option>
#           <option value="/worldcup/archive/france1938/">
#            france1938
#           </option>
#           <option value="/worldcup/archive/italy1934/">
#            italy1934
#           </option>
#           <option value="/worldcup/archive/uruguay1930/">
#            uruguay1930
#           </option>
#          </select>
#         </div>
#         <script language="javascript" type="text/javascript">
#          var editionDropdown = document.getElementById('edition-selector');
#     editionDropdown.addEventListener('change', function (event) {
#
#       if (event && event.target && event.target.value) {
#         window.location.assign(event.target.value);
#       }
#
#     });
#         </script>
#        </div>
#        <div class="fi-section-header__social">
#         <ul class="fi-social-channels--svg">
#          <li>
#           <a class="fi-social-channels__fb--f" href="https://www.facebook.com/fifaworldcup" target="_blank">
#            <svg class="fi-svg-icon fi-icon-facebook-noframe">
#             <use xlink:href="#icon-facebook-noframe">
#             </use>
#            </svg>
#           </a>
#          </li>
#          <li>
#           <a class="fi-social-channels__tw--circle" href="https://twitter.com/FifaWorldCup" target="_blank">
#            <svg class="fi-svg-icon fi-icon-tw-noframe">
#             <use xlink:href="#icon-tw-noframe">
#             </use>
#            </svg>
#           </a>
#          </li>
#          <li>
#           <a class="fi-social-channels__instagram" href="https://www.instagram.com/fifaworldcup/" target="_blank">
#            <svg class="fi-svg-icon fi-icon-instagram-noframe">
#             <use xlink:href="#icon-instagram-noframe">
#             </use>
#            </svg>
#           </a>
#          </li>
#          <li>
#           <a class="fi-social-channels__youtube" href="https://www.youtube.com/FIFATV" target="_blank">
#            <svg class="fi-svg-icon fi-icon-youtube-noframe">
#             <use xlink:href="#icon-youtube-noframe">
#             </use>
#            </svg>
#           </a>
#          </li>
#          <li>
#           <a class="fi-social-channels__we--f" href="https://www.weibo.com/FIFAWorldCup?is_hot=1" target="_blank">
#            <svg class="fi-svg-icon fi-icon-weibo-noframe">
#             <use xlink:href="#icon-weibo-noframe">
#             </use>
#            </svg>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="fi-pageheader">
#    <script type="text/javascript">
#     requirejs(['/CompiledAssets/js/modules/playerMenuItems.js?t=912362e09670c30b342ead955906b01a']);
#    </script>
#    <div class="fi-ph" data-edtelements="/worldcup/players/_libraries/_editorial_elements" data-player="201200">
#     <div class="fi-ph__container">
#      <div class="fi-ph__player">
#       <h1 class="fi-ph__player__name">
#        CRISTIANO RONALDO
#       </h1>
#      </div>
#     </div>
#     <div class="fi-page-nav">
#      <ul class="nav fi-page-nav__menu">
#       <li data-tag="player-overview">
#        <a href="/worldcup/players/player/201200/">
#         Overview
#        </a>
#       </li>
#       <li class="active " data-tag="player-profile">
#        <a href="/worldcup/players/player/201200/profile/">
#         Profile
#        </a>
#       </li>
#       <li data-tag="player-news">
#        <a href="/worldcup/players/player/201200/news/">
#         News
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="content-wrap fi-article-template " data-item-by-slug="False">
#    <div class="fi-boxed-page">
#     <article class="d3-o-article fi-article container-fluid ">
#      <div class="row">
#       <div class="row fi-p--profile">
#        <div class="col-xs-12 col-sm-6 col-flex">
#         <div class="box-content clearfix">
#          <a class="fi-p--link no-link" data-player-id="201200" href="javascript:void(0)">
#           <div class="fi-p ">
#            <div class="fi-p__picture">
#             <svg class="fi-clip-svg" id="" viewbox="0 0 200 200">
#              <image alt="" class="image-r image-responsive" height="100%" width="100%" xlink:href="https://api.fifa.com/api/v1/picture/players/2018fwc/201200_sq-300_jpg?allowDefaultPicture=true">
#
#             </svg>
#             <div class="fi-p__flag" data-countrycode="por">
#              <div class="fi-p__flag__wrapper">
#               <img alt="POR" class="fi-POR fi-flag--4" src="https://api.fifa.com/api/v1/picture/flags-fwc2018-4/por" title="POR"/>
#              </div>
#             </div>
#            </div>
#            <div class="fi-p__wrapper-text">
#             <div class="fi-p__name">
#              CRISTIANO RONALDO
#             </div>
#             <div class="fi-p__country">
#              Portugal
#             </div>
#             <div class="fi-p__role">
#              Forward
#             </div>
#            </div>
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="col-xs-12 col-sm-6 col-flex fi-p__profile-info">
#         <div class="row">
#          <div class="col-xs-6 col-flex">
#           <div class="fi-p__profile-number">
#            Age
#            <div class="fi-p__profile-number__number">
#             35
#            </div>
#           </div>
#          </div>
#          <div class="col-xs-6 col-flex">
#           <div class="fi-p__profile-number">
#            Height
#            <div class="fi-p__profile-number__number">
#             187.0 cm
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="row">
#          <div class="col-xs-12 col-flex">
#           <div class="fi-p__profile-text fi-p__profile-text--uppercase">
#            Date of Birth
#            <span>
#             05 February 1985
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="row">
#          <div class="col-xs-12 col-flex">
#           <div class="row">
#            <div class="col-xs-6 col-flex fi-profile__caps">
#             <div class="fi-p__profile-number">
#              International Caps
#              <div class="fi-p__profile-number__number">
#               164
#              </div>
#             </div>
#            </div>
#            <div class="col-xs-6 col-flex fi-profile__goals">
#             <div class="fi-p__profile-number">
#              International Goals
#              <div class="fi-p__profile-number__number">
#               85
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="row">
#          <div class="col-xs-12 col-flex">
#          </div>
#         </div>
#        </div>
#       </div>
#       <svg height="0" style="position: absolute; width: 0; height: 0;" version="1.1" width="0" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#        <defs>
#         <clippath id="clip-drop">
#          <path d="M99.851 194.226c.137.128.137.257.137.257s0-.064.138-.257c30.97-29.164 77.526-26.331 93.874-55.88C214.899 100.686 180.619 0 100.263 0h-.551C19.356 0-14.857 100.686 5.975 138.346c16.347 29.612 62.905 26.717 93.876 55.88z">
#          </path>
#         </clippath>
#        </defs>
#       </svg>
#       <div class="fi-adv-placeholder mode-none fi-adv-bigleaderboard" data-adunit="/8584/fifa.com" data-adunit-custom="" data-advsize="bigleaderboard" id="gpt-fi-adv-inpage-09baae89-266d-46db-8fba-8112828b1c34">
#       </div>
#       <script type="text/javascript">
#        requirejs(['/CompiledAssets/js/modules/table.js?t=fde50204def0fe8e844500172dc99487']);
#       </script>
#       <div class="d3-o-article__header fi-article__header " data-slug="keep-pending--por--cristiano-ronaldo-129w-2946884">
#        <div class="col-xs-12 fi-icon-logo-com">
#        </div>
#       </div>
#       <div class="d3-o-article__body fi-article__body ">
#        <script type="text/javascript">
#         // Temporary patch to manage external link with target="_blank". Remove it when NGF fix your side
#     $(document).ready(function () {
#       var articleLinks = $('.fi-o-article__body-part--text a');
#       var i = 0;
#       for (i; i < articleLinks.length; i++) {
#         var _url = articleLinks[i].href;
#         if (_url.indexOf('.fifa.com') === -1) {
#           articleLinks[i].target = '_blank';
#         }
#       }
#     });
#        </script>
#        <div class="col-xs-12 col-sm-10 col-md-8 col-sm-offset-1 col-md-offset-2 d3-o-article__body-part--text fi-o-article__body-part--text">
#         <p>
#          The Real Madrid forward is Portugal’s captain, most capped player and leading all-time goalscorer. Still supremely fit and as committed as ever, he is more of a penalty box operator these days, having lost none of his scoring touch or his gift for breaking records.
#         </p>
#         <p>
#          A formidable dribbler and a considerable aerial threat, Ronaldo is noted for his power, speed and instinct, qualities that have seen him named as the world’s best player on five occasions by FIFA. The most special of all the many honours he has won, however, is UEFA EURO 2016, his country’s first major trophy, which he had the honour of raising as skipper. The 2018 FIFA World Cup Russia™ will be his fourth world finals appearance.
#         </p>
#        </div>
#       </div>
#       <script type="text/javascript">
#        digitalData.page.attributes.contentID = '8887dc15-8475-4654-9b5e-b388d218b220';
#   digitalData.page.attributes.xLangContentID = '609a6893-cc73-45d8-8280-ae776fb10789';
#   digitalData.page.attributes.contentName = 'Cristiano Ronaldo';
#   digitalData.page.attributes.type = 'article';
#
#
#   digitalData.page.pageInfo.issueDate = '30/04/2018 08:28:55';
#
#   digitalData.page.pageInfo.author = '';
#       </script>
#       <script language="javascript" type="text/javascript">
#        $(document).ready(function () {
#
#     var offset_desktop = 600;
#     var offset_tablet = 580;
#     var offset_mobile = 350;
#     var offsetHiddenAdv = offset_desktop;
#
#     if (typeof Utility !== 'undefined') {
#       offsetHiddenAdv = (Utility.isMobile() ? offset_mobile : (Utility.isTablet() ? offset_tablet : offset_desktop));
#     }
#
#     $(window).on('scroll', function () {
#
#       var adv = $('.fi-article__adv');
#       var windowOffset = $(window).scrollTop();
#
#       //Utility.log(windowOffset);
#
#       if (windowOffset > offsetHiddenAdv) {
#         adv.addClass('hide-adv');
#       }
#       else {
#         adv.removeClass('hide-adv');
#       }
#     });
#
#   });
#       </script>
#      </div>
#     </article>
#    </div>
#   </div>
#   <!--------------------------------------------------------------------------------
#          P R E   F O O T E R
# --------------------------------------------------------------------------------->
#   <section class="section fi-pre-footer ">
#    <div class="container-fluid">
#     <div class="fi-footer-link">
#      <!--SOCIAL-->
#      <div class="fi-footer-link__social">
#       <h4 class="fi-social-channels__title">
#        Follow us on
#       </h4>
#       <ul class="fi-social-channels--svg">
#        <li>
#         <a class="fi-social-channels__fb--f" href="https://www.facebook.com/fifaworldcup" target="_blank">
#          <svg class="fi-svg-icon fi-icon-facebook-noframe">
#           <use xlink:href="#icon-facebook-noframe">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li>
#         <a class="fi-social-channels__tw--circle" href="https://twitter.com/FifaWorldCup" target="_blank">
#          <svg class="fi-svg-icon fi-icon-tw-noframe">
#           <use xlink:href="#icon-tw-noframe">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li>
#         <a class="fi-social-channels__instagram" href="https://www.instagram.com/fifaworldcup/" target="_blank">
#          <svg class="fi-svg-icon fi-icon-instagram-noframe">
#           <use xlink:href="#icon-instagram-noframe">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li>
#         <a class="fi-social-channels__youtube" href="https://www.youtube.com/FIFATV" target="_blank">
#          <svg class="fi-svg-icon fi-icon-youtube-noframe">
#           <use xlink:href="#icon-youtube-noframe">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li>
#         <a class="fi-social-channels__we--f" href="https://www.weibo.com/FIFAWorldCup?is_hot=1" target="_blank">
#          <svg class="fi-svg-icon fi-icon-weibo-noframe">
#           <use xlink:href="#icon-weibo-noframe">
#           </use>
#          </svg>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <ul class="nav fi-footer-link__menu">
#       <li data-tag="">
#        <a href="/worldcup/matches/">
#         Matches
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/teams/">
#         Teams
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/groups/">
#         Groups
#        </a>
#       </li>
#       <li class="active " data-tag="">
#        <a href="/worldcup/players/">
#         Players
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/statistics/">
#         Statistics
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/destination/">
#         Destination
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/fan-zone/">
#         Fan Zone
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/awards/">
#         Awards
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/organisation/ticketing/index.html">
#         Ticketing
#        </a>
#       </li>
#       <li data-tag="">
#        <a href="/worldcup/classic/">
#         Classic
#        </a>
#       </li>
#      </ul>
#      <!--SEARCH-->
#      <div class="fi-search">
#       <div class="form-group">
#        <form action="/search/index" method="get">
#         <input class="fi-search__text" data-required="true" maxlength="100" name="q" placeholder="Search on FIFA.com" title="Search" type="text"/>
#         <div class="fi-search__submit-wrap">
#          <label>
#           <input class="btn btn-primary fi-btn--submit" type="submit" value=""/>
#           <svg class="fi-svg-icon icon-search">
#            <use xlink:href="#icon-search">
#            </use>
#           </svg>
#          </label>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!--------------------------------------------------------------------------------
# E N D  P R E   F O O T E R
# --------------------------------------------------------------------------------->
#   <div class="fi-back-to-top" data-offset-top="60" data-spy="affix">
#    <a>
#     <i class="fi-icon fi-icon-up">
#     </i>
#    </a>
#   </div>
#   <footer class="fi-site-footer hidden-print">
#    <div class="container-fluid">
#     <div class="row fi-site-footer-elements">
#      <div class="fi-site-footer__copyright col-xs-12 hidden-md hidden-lg">
#       <i class="fi-icon fi-icon-logo">
#       </i>
#      </div>
#      <div class="fi-site-footer__right col-xs-12 col-md-12">
#       <div class="fi-site-footer__row1">
#        <ul class="fi-footer-menu">
#         <li>
#          <a href="/legal/terms-of-service">
#           Terms of Service
#          </a>
#         </li>
#         <li>
#          <a href="/legal/privacy-policy">
#           Privacy Policy
#          </a>
#         </li>
#         <li>
#          <a href="/legal/cookie-policy">
#           Cookie Policy
#          </a>
#         </li>
#         <li>
#          <a href="/legal/downloads">
#           Downloads
#          </a>
#         </li>
#         <li>
#          <a href="/faq">
#           Contact FIFA
#          </a>
#         </li>
#         <li>
#          <a href="/mobile/">
#           Mobile Apps
#          </a>
#         </li>
#         <li>
#          <a href="/about-fifa/who-we-are/home-of-fifa/careers/">
#           Jobs
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="fi-site-footer__copyright col-md-1 visible-md visible-lg">
#       <svg class="fi-svg-icon fifa-icon">
#        <use xlink:href="#fifa-icon">
#        </use>
#       </svg>
#      </div>
#      <div class="fi-site-footer__language col-xs-12 col-md-2">
#       <div class="fi-footer__language dropup">
#        <div class="dropdown fi-select-wrapper fi-select__languages" data-lang="en-GB">
#         <button class="btn btn-select dropdown-toggle" data-toggle="dropdown" type="button">
#          <span class="fi-selected-item">
#          </span>
#         </button>
#         <ul class="dropdown-menu">
#          <li data-value="en-GB">
#           <a href="https://en.fifa.com">
#            English
#           </a>
#          </li>
#          <li data-value="de-DE">
#           <a href="https://de.fifa.com">
#            Deutsch
#           </a>
#          </li>
#          <li data-value="fr-FR">
#           <a href="https://fr.fifa.com">
#            Français
#           </a>
#          </li>
#          <li data-value="es-ES">
#           <a href="https://es.fifa.com">
#            Español
#           </a>
#          </li>
#          <li data-value="ar-SA">
#           <a href="https://ar.fifa.com">
#            عربي
#           </a>
#          </li>
#          <li data-value="ru-RU">
#           <a href="https://ru.fifa.com">
#            Русский
#           </a>
#          </li>
#          <li data-value="ch-CH">
#           <a href="https://fifaofficial.cn">
#            简体中文
#           </a>
#          </li>
#         </ul>
#         <select class="fi-select">
#          <option data-abbr="EN" value="en-GB">
#           English
#          </option>
#          <option data-abbr="DE" value="de-DE">
#           Deutsch
#          </option>
#          <option data-abbr="FR" value="fr-FR">
#           Français
#          </option>
#          <option data-abbr="ES" value="es-ES">
#           Español
#          </option>
#          <option data-abbr="AR" value="ar-SA">
#           عربي
#          </option>
#          <option data-abbr="RU" value="ru-RU">
#           Русский
#          </option>
#          <option data-abbr="CH" value="ch-CH">
#           简体中文
#          </option>
#         </select>
#         <i class="fi-icon fi-icon-down">
#         </i>
#        </div>
#       </div>
#      </div>
#      <div class="fi-site-footer__row2 col-xs-12 col-md-6">
#       <span>
#        Copyright ©1994 - 2020 FIFA. All rights reserved
#       </span>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div id="fb-root">
#   </div>
#   <script type="text/javascript">
#    window.___gcfg = {
#     lang: 'en-GB',
#     parsetags: 'onload'
#   };
#   </script>
#   <script type="text/javascript">
#    //digitalData.page.pageInfo.pageName = (function () {
#   //  var sb = [];
#   //  sb.push(digitalData.page.attributes.section);
#   //  if (digitalData.page.attributes.level1) {
#   //    sb.push(digitalData.page.attributes.level1);
#   //  }
#   //  if (digitalData.page.attributes.level2) {
#   //    sb.push(digitalData.page.attributes.level2);
#   //  }
#   //  if (digitalData.page.attributes.level3) {
#   //    sb.push(digitalData.page.attributes.level3);
#   //  }
#   //  if (digitalData.page.attributes.level4) {
#   //    sb.push(digitalData.page.attributes.level4);
#   //  }
#   //  if (digitalData.page.pageInfo.pageID) {
#   //    sb.push(digitalData.page.pageInfo.pageID);
#   //  }
#   //  return sb.join(':');
#   //}());
#   //digitalData.pageInstanceID = (function () {
#   //  return [digitalData.page.pageInfo.pageName, digitalData.page.pageInfo.sysEnv].join(':');
#   //}());
#   </script>
#   <script type="text/javascript">
#    function initSatellite(forceInit) {
#
#         var isFF = navigator.userAgent.indexOf("Firefox") !== -1;
#
#         if (!isFF) {
#           if (typeof _satellite !== 'undefined') {
#             _satellite.pageBottom();
#           }
#         }
#         if (forceInit) {
#           countdown = 10;
#           pg_satellite();
#         }
#
#         var countdown = 10;
#
#         $(document).ready(function () {
#           if (isFF) {
#             pg_satellite();
#           }
#         });
#
#         function pg_satellite() {
#           if (typeof _satellite !== 'undefined') {
#             _satellite.pageBottom();
#           }
#           else if (countdown > 0) {
#             setTimeout(pg_satellite, 1000);
#             countdown--;
#           }
#         }
#       }
#
#       initSatellite(false);
#   </script>
#  </body>
# </html>

# %%
#Scraping Data
name = soup.find("div",{"class":"fi-p__name"})
print(name)
# Out:
# <div class="fi-p__name">
#           CRISTIANO RONALDO
#         </div>

# %%
#Scraping Data
name = soup.find("div",{"class":"fi-p__name"}).text
print(name)
# Out:
#           CRISTIANO RONALDO

# %%
#Scraping Data
player_name = soup.find("div",{"class":"fi-p__name"}).text.replace("\n","").strip()
print(name)
# Out:
#           CRISTIANO RONALDO

# %%
player_country = soup.find("div",{"class":"fi-p__country"}).text.replace("\n","").strip()

# %%
player_country
# Out:
# 'Portugal'

# %%
player_role = soup.find("div",{"class":"fi-p__role"}).text.replace("\n","").strip()
player_age = soup.find("div",{"class":"fi-p__profile-number__number"}).text.replace("\n","").strip()
player_height = soup.find_all("div",{"class":"fi-p__profile-number__number"})[1].text.replace("\n","").strip()
player_int_caps = soup.find_all("div",{"class":"fi-p__profile-number__number"})[2].text.replace("\n","").strip()
player_int_goals = soup.find_all("div",{"class":"fi-p__profile-number__number"})[3].text.replace("\n","").strip()

print(player_name,"\n",player_country,"\n",player_role,"\n",player_age,"years \n",player_height,"\n",player_int_caps,"caps \n",player_int_goals,"goals")
# Out:
# CRISTIANO RONALDO
#  Portugal
#  Forward
#  35 years
#  187.0 cm
#  164 caps
#  85 goals

# %%
import pandas as pd

request = requests.get("https://www.fifa.com/worldcup/players/_libraries/byposition/[id]/_players-list")
soup = BeautifulSoup(request.content,"html.parser")

#Empty list to store data
id_list = []
#Iterate to find all IDs
for ids in range(0,736):
    all = soup.find_all("a","fi-p--link")[ids]
    id_list.append(all['data-player-id'])
    
#Data Frame to store scrapped data
df = pandas.DataFrame({
"Ids":id_list
})
df.to_csv('player_ids.csv', index = False)
print(df,"\n Success")

# %%
id_list[1]
# Out:
# '202638'
